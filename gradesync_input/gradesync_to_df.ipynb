# %%
import pandas as pd
import numpy as np
import os
import sys
import argparse
import logging
import json
import re

# %%
# # Create an output folder if it doesn't exist
# output_folder = os.path.join(os.path.dirname(__file__), 'output')
# if not os.path.exists(output_folder):
#     os.makedirs(output_folder)

# %%
# Google Sheets API
from googleapiclient.discovery import build
from google.oauth2 import service_account
from google.auth.transport.requests import Request
from google.auth.exceptions import RefreshError

# %%
import os

# Assuming your credentials are in a folder named 'config' in the current working directory
config_folder = os.path.join(os.getcwd(), 'config')
credentials_path = os.path.join(config_folder, 'credentials.json')

if not os.path.exists(credentials_path):
    print(f"Credentials file not found: {credentials_path}")
else:
    print(f"Credentials path found: {credentials_path}")
# Out:
# Credentials path found: /Users/mananbhargava/Documents/Workspaces/dan-cs-ed/remind/gradesync_input/config/credentials.json

# %%
# Sheet & credentials config
google_sheet_id = '11H0hRtJOHCy59jaxbdRSp7JhDtkaiOibvexZ4Shj4wE'
google_sheet_credentials = 'credentials.json'
config_folder = os.path.join(os.getcwd(), 'config')
credentials_path = os.path.join(config_folder, 'credentials.json')

if not os.path.exists(credentials_path):
    logging.error(f"Credentials file not found: {credentials_path}")
    sys.exit(1)

# %%
def get_credentials():
    try:
        creds = service_account.Credentials.from_service_account_file(
            credentials_path,
            scopes=['https://www.googleapis.com/auth/spreadsheets.readonly']
        )
        return creds
    except Exception as e:
        logging.error(f"Error getting credentials: {e}")
        sys.exit(1)

def get_all_tab_names(sheet_id, credentials):
    try:
        service = build('sheets', 'v4', credentials=credentials)
        spreadsheet = service.spreadsheets().get(spreadsheetId=sheet_id).execute()
        sheet_metadata = spreadsheet.get('sheets', [])
        tab_names = [sheet['properties']['title'] for sheet in sheet_metadata]
        return tab_names
    except Exception as e:
        logging.error(f"Error fetching tab names: {e}")
        sys.exit(1)

def get_google_sheet_data(sheet_id, range_name, credentials):
    try:
        service = build('sheets', 'v4', credentials=credentials)
        sheet = service.spreadsheets()
        result = sheet.values().get(spreadsheetId=sheet_id, range=range_name).execute()
        return result.get('values', [])
    except Exception as e:
        logging.error(f"Error getting data from Google Sheet: {e}")
        sys.exit(1)

def convert_to_dataframe(data):
    """
    Convert raw sheet data to a cleaned DataFrame, padding short rows
    """
    try:
        headers = data[0]
        rows = data[1:]

        # Pad shorter rows with empty strings to match header length
        padded_rows = [row + [''] * (len(headers) - len(row)) for row in rows]

        df = pd.DataFrame(padded_rows, columns=headers)
        return df
    except Exception as e:
        logging.error(f"Error converting data to DataFrame: {e}")
        sys.exit(1)

# %%
creds = get_credentials()
creds

# %%
tab_names = get_all_tab_names(google_sheet_id, creds)
tab_names
# Out:
# ['Roster',
#  'Labs',
#  'Pyturis',
#  'Discussions',
#  'Sheet8',
#  'Projects',
#  'Lecture Quizzes',
#  'Midterms',
#  'Postterms',
#  'Lecture Quiz 4: Iteration',
#  'Lecture Quiz 12: Higher-Order Functions',
#  'Lab 4: Lists + Loops (Conceptual)',
#  'Lab 4: Lists + Loops (code)',
#  'Postterm 3: With Snap! (HOFs)',
#  'Postterm 3: With Snap! (Recursion)',
#  'Lab 5: Lists + HOFs (Conceptual)',
#  'Lecture Quiz 21: Generative AI',
#  'Project 3: 2048',
#  'Lecture Quiz 2: Functions',
#  'Lecture Quiz 1: Welcome to CS10 u0026 Abstraction',
#  'Lab 5: Lists + HOFs (Code)',
#  'Lab 2: Build Your Own Blocks (Conceptual)',
#  'Lab 2: Build Your Own Blocks (Code)',
#  'Discussion 1: Welcome to CS10!',
#  'Lab 8: Boards (Conceptual)',
#  'Discussion 2: Numeral Representation + Control Structurest',
#  'Discussion 3: Domain/Range, Scoping, Iteration, Listst',
#  'Project 1: Wordlexe2x84xa2-lite',
#  'Lab 3: Conditionals, Reporters, u0026 Abstraction (Conceptual)',
#  'Lab 3: Conditionals, Reporters u0026 Abstraction (Code)',
#  'Lab 6: Algorithms (Code)',
#  'Lecture Quiz 14: Computers in Education ',
#  'Lecture Quiz 5: Lists, Scoping, u0026 HOFs',
#  'Lecture Quiz 11: Testing + 2048',
#  'Lecture Quiz 6: Algorithms',
#  'Lecture Quiz 3: Numbers and Abstraction',
#  'Lecture Quiz 7: Algorithmic Complexity',
#  'Lab 7: Algorithmic Complexity (Code)',
#  'Lecture Quiz 8: Linear Recursion',
#  'Discussion 4: Algorithmic Complexity + Quest Practice',
#  'Lab 10: Recursive Reporters (Conceptual)',
#  'Discussion 5: Nested Lists + Recursiont',
#  'Lecture Quiz 9: Recursion II (Fractals)',
#  'Lab 9: Trees and Fractals (Code)',
#  'Lab 9: Trees and Fractals (Conceptual)',
#  'Discussion 6: More Recursion!t',
#  'Lab 10: Recursive Reporters (Code)',
#  'Lecture Quiz 13: Saving the World with Computing (Guest Lecture)',
#  'Lecture Quiz 10: Recursion III (Tree Recursion)',
#  'Discussion 7: HOFs, Lambdas, Debuggingt',
#  'Midterm 1 Fractal (with Snap!)',
#  'Lab 12: HOFs and Functions as Data (Code)',
#  'Lab 12: HOFs and Functions as Data (Conceptual)',
#  'Lecture Quiz 17: Python I - Intro',
#  'Lecture Quiz 15: Programming Paradigms',
#  'Project 4: Artifact + Documentation',
#  'Lab 15: Data Structures in Python (Code)',
#  'Lab 15: Data Structures in Python (Conceptual)',
#  'Lecture Quiz 18: Python II - Data Structures',
#  'Discussion 9: OOP, Clones, Events',
#  'Lab 19: Data Science (conceptual)',
#  'Lecture Quiz 23: Python III - Game Theory**',
#  'Discussion 12: Concurrency + Postterm Practicet',
#  'Lab 17: Text Processing in Python (Conceptual)',
#  'Discussion 11: Data Structures',
#  'Lecture Quiz 24: Python V - OOP',
#  'Lab 16: Concurrency u0026 Parallelism',
#  'Project 6: Final Project Proposal',
#  'Discussion 13: Concurrency + Python HOFst',
#  'Lecture Quiz 19: Concurrency',
#  'Project 4: Comments + Peer Feedback',
#  'Lecture Quiz 21: Ethics in AI',
#  'Postterm 4: With Snap!',
#  'Project 6: Final Project Submission',
#  'Lab 17: Text Processing in Python (Code)',
#  'Lab 14: Welcome to Python (Code)',
#  'Project 2: Spelling Bee',
#  'Lab 19: Data Science (code)',
#  'Lab 11: Testing + 2048 (Conceptual)',
#  'Lab 14: Welcome to Python (Conceptual)',
#  'Lab 6: Algorithms (Conceptual)',
#  'Lab 7: Algorithmic Complexity (Conceptual)',
#  'Lab 8: Boards (Code)',
#  'Practice Midterm: With Snap! (Fractal)',
#  'Lecture Quiz 20: Human Computer Interaction (Guest Lecture)',
#  'Lecture Quiz 25: Alumni Panel',
#  'Lecture Quiz 26: Conclusion and Farewell!',
#  'Midterm 2: with Snap! (Fractal)',
#  'Lecture Quiz 16. OOP in Snap!',
#  'Project 5: Final Project Proposal',
#  'Project 5: Final Project Submission',
#  'Midterm 3: with Snap! (Fractal)']

# %%
tab = 'Project 3: 2048'
if tab not in tab_names:
    logging.error(f"Tab name '{tab}' not found in the Google Sheet.")
    sys.exit(1)

# %%
print(f"\n Parsing tab: {tab}")
range_str = f"{tab}"
raw_data = get_google_sheet_data(google_sheet_id, range_str, creds)
raw_data
# if not raw_data or len(raw_data) < 2:
#   print(f"Skipping {tab} (no data)")
# Out:
#  Parsing tab: Project 3: 2048
# [["b'First Name",
#   'Last Name',
#   'SID',
#   'Email',
#   'Sections',
#   'Total Score',
#   'Max Points',
#   'Status',
#   'Submission ID',
#   'Submission Time',
#   'Lateness (H:M:S)',
#   'View Count',
#   'Submission Count',
#   '1: Autograder (35.0 pts)'],
#  ['Anita',
#   'Qian',
#   '3040005244',
#   'anita_qian@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '314621931',
#   '2025-03-05 10:45:24 -0800',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Malachite',
#   'McEvoy',
#   '3036547996',
#   'malachitemcevoy@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '314680106',
#   '2025-03-05 13:17:20 -0800',
#   '0:00:00',
#   '0',
#   '2',
#   '35'],
#  ['Abigail',
#   'Johnson',
#   '3040928660',
#   'abigail.johnson@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '314713498',
#   '2025-03-05 14:46:33 -0800',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Jack',
#   'Hulse',
#   '3040081294',
#   'johnhulse@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '314713498',
#   '2025-03-05 14:46:33 -0800',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Kelly',
#   'Chou',
#   '3038568093',
#   'kelly0919@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '30.35',
#   '35',
#   'Graded',
#   '314886910',
#   '2025-03-06 00:34:41 -0800',
#   '0:00:00',
#   '0',
#   '1',
#   '30.35'],
#  ['Madeira',
#   'Lowe',
#   '3036690193',
#   'maddielowe@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '315144710',
#   '2025-03-06 17:29:22 -0800',
#   '0:00:00',
#   '0',
#   '2',
#   '35'],
#  ['Simon',
#   'Wimmer',
#   '3040927802',
#   'simon.wimmer@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '315144710',
#   '2025-03-06 17:29:22 -0800',
#   '0:00:00',
#   '0',
#   '2',
#   '35'],
#  ['Priscilla',
#   'Shih',
#   '3040151286',
#   'prishi@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '315544681',
#   '2025-03-07 19:04:34 -0800',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Devon',
#   'Akiyama',
#   '3036618589',
#   'devon-akiyama@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '315544681',
#   '2025-03-07 19:04:34 -0800',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Xiaolei',
#   'Jiang',
#   '3040943558',
#   'xiaoleijiang@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '315747350',
#   '2025-03-09 03:15:53 -0700',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Yutong',
#   'Sun',
#   '3040864726',
#   'sun0226@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '316378144',
#   '2025-03-11 16:11:03 -0700',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Jialing',
#   'Zhou',
#   '3040940542',
#   'jialingzhou@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '316378144',
#   '2025-03-11 16:11:03 -0700',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Jiuxi',
#   'Wang',
#   '3039900360',
#   'jiuxi_wang@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '316702509',
#   '2025-03-12 16:11:56 -0700',
#   '0:00:00',
#   '0',
#   '7',
#   '35'],
#  ['Qiqing',
#   'Deng',
#   '3040948524',
#   'dqq22071011@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '316702509',
#   '2025-03-12 16:11:56 -0700',
#   '0:00:00',
#   '0',
#   '2',
#   '35'],
#  ['Yiqian',
#   'Chen',
#   '3040759465',
#   'chenyiqian1000@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '19.3775',
#   '35',
#   'Graded',
#   '316772165',
#   '2025-03-12 19:55:47 -0700',
#   '0:00:00',
#   '0',
#   '1',
#   '19.3775'],
#  ['Zhuoyin',
#   'Hu',
#   '3040935381',
#   'huzhuoyin@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '317719592',
#   '2025-03-16 17:05:31 -0700',
#   '0:00:00',
#   '0',
#   '2',
#   '35'],
#  ['Zijian',
#   'Qiu',
#   '3040942973',
#   'jasonqiu12@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '317719592',
#   '2025-03-16 17:05:31 -0700',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Minseo',
#   'Yoon',
#   '3040799830',
#   'minseo0223@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '18.19',
#   '35',
#   'Graded',
#   '317928614',
#   '2025-03-17 14:27:35 -0700',
#   '0:00:00',
#   '0',
#   '2',
#   '18.19'],
#  ['Liangcheng',
#   'Zhang',
#   '3040950656',
#   '12012616lc@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '317968949',
#   '2025-03-17 16:58:27 -0700',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Yizhou',
#   'Yuan',
#   '3040942908',
#   'yujoo_ivy@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '317968949',
#   '2025-03-17 16:58:27 -0700',
#   '0:00:00',
#   '0',
#   '2',
#   '35'],
#  ['Alex',
#   'Xiao',
#   '3038531186',
#   'xyux@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '30.35',
#   '35',
#   'Graded',
#   '317970184',
#   '2025-03-17 17:04:30 -0700',
#   '0:00:00',
#   '0',
#   '1',
#   '30.35'],
#  ['Gabriella',
#   'Rachal',
#   '3040328684',
#   'gcrachal14@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '317970977',
#   '2025-03-17 17:06:42 -0700',
#   '0:00:00',
#   '0',
#   '5',
#   '35'],
#  ['Adriana',
#   'Ho',
#   '3039985705',
#   'adrianaho@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '318007355',
#   '2025-03-17 19:37:28 -0700',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Sofia',
#   'Gonzalez',
#   '3040044257',
#   'sofia_gonzalez@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '318007355',
#   '2025-03-17 19:37:28 -0700',
#   '0:00:00',
#   '0',
#   '1',
#   '35'],
#  ['Augus',
#   'Lu',
#   '3036656276',
#   'ninglu@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '12.8425',
#   '35',
#   'Graded',
#   '318045625',
#   '2025-03-17 22:21:11 -0700',
#   '0:00:00',
#   '0',
#   '2',
#   '12.8425'],
#  ['Carolina',
#   'Cabezas',
#   '3040308547',
#   'caroadamary@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '32.665',
#   '35',
#   'Graded',
#   '318338275',
#   '2025-03-19 00:21:57 -0700',
#   '24:22:57',
#   '0',
#   '1',
#   '32.665'],
#  ['Precious',
#   'Rios',
#   '3039926074',
#   'preciousrios613@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '32.665',
#   '35',
#   'Graded',
#   '318338275',
#   '2025-03-19 00:21:57 -0700',
#   '24:22:57',
#   '0',
#   '1',
#   '32.665'],
#  ['Riya',
#   'Goel',
#   '3038772349',
#   'riyagoel@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '318423863',
#   '2025-03-19 11:13:17 -0700',
#   '35:14:17',
#   '0',
#   '1',
#   '35'],
#  ['Aidan',
#   'Fuentes-Yip',
#   '3039887737',
#   'acfuentes@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '318647890',
#   '2025-03-20 04:27:02 -0700',
#   '52:28:02',
#   '0',
#   '2',
#   '35'],
#  ['Wanying',
#   'Luo',
#   '3040952216',
#   'luoluobright@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '318790124',
#   '2025-03-20 15:06:30 -0700',
#   '63:07:30',
#   '0',
#   '1',
#   '35'],
#  ['Alex',
#   'Chen',
#   '3040081632',
#   'alexychen@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '318810654',
#   '2025-03-20 16:08:39 -0700',
#   '64:09:39',
#   '0',
#   '1',
#   '35'],
#  ['Joyce',
#   'Kei',
#   '3040233706',
#   'joyce_kei@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '318810654',
#   '2025-03-20 16:08:39 -0700',
#   '64:09:39',
#   '0',
#   '4',
#   '35'],
#  ['Emilie',
#   'Yajima',
#   '3040923954',
#   'emilie1217@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '25.66',
#   '35',
#   'Graded',
#   '318873359',
#   '2025-03-20 20:07:01 -0700',
#   '68:08:01',
#   '0',
#   '5',
#   '25.66'],
#  ['Ruisi',
#   'Liu',
#   '3039890220',
#   'ruisi_liu@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '318904676',
#   '2025-03-20 22:19:03 -0700',
#   '70:20:03',
#   '0',
#   '3',
#   '35'],
#  ['Yanlin',
#   'Zhao',
#   '3040466419',
#   'yanlinzhao@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '318904676',
#   '2025-03-20 22:19:03 -0700',
#   '70:20:03',
#   '0',
#   '6',
#   '35'],
#  ['Brandon',
#   'Yeh',
#   '3040617947',
#   'brandon_yeh@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '35',
#   '35',
#   'Graded',
#   '320850899',
#   '2025-03-28 20:50:41 -0700',
#   '260:51:41',
#   '0',
#   '1',
#   '35'],
#  ['test2', 'test2', '', 'test2@test.com', '', '', '35', 'Missing'],
#  ['test1', 'test1', '', 'test1@test.com', '', '', '35', 'Missing'],
#  ['test3', 'test3', '', 'test3@test.com', '', '', '35', 'Missing'],
#  ['test4', 'test4', '', 'test4@test.com', '', '', '35', 'Missing'],
#  ['Rishi',
#   'Kundu',
#   'UID:1732360',
#   'rkundu@berkeley.edu',
#   'Incomplete / Continuing Work',
#   '',
#   '35',
#   'Missing'],
#  ['Vanessa',
#   'Nguyen',
#   '3036804730',
#   'vanessa.nguyen@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Tilema',
#   'Latu',
#   '3037338261',
#   'tilemalatu@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Leona',
#   'Katibah',
#   '',
#   'leonakatibah@berkeley.edu',
#   '',
#   '',
#   '35',
#   'Missing'],
#  ['Liz',
#   'Martinez',
#   '3038326956',
#   'lizbeth.martinez@berkeley.edu',
#   'Incomplete / Continuing Work',
#   '',
#   '35',
#   'Missing'],
#  ['Wendi',
#   'Lopez',
#   'UID:1808816',
#   'wlopez26@berkeley.edu',
#   'Incomplete / Continuing Work',
#   '',
#   '35',
#   'Missing'],
#  ['Qurratul',
#   'Sanjida',
#   '',
#   'qurratulain.508@berkeley.edu',
#   '',
#   '',
#   '35',
#   'Missing'],
#  ['Keon',
#   'Soltani',
#   '',
#   'keon@berkeley.edu',
#   'Incomplete / Continuing Work',
#   '',
#   '35',
#   'Missing'],
#  ['Khushi',
#   'Kethana',
#   '3037674837',
#   'khushikethana@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Hyun Woo',
#   'Song',
#   '3038359521',
#   'hsong423@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Giovanni',
#   'Chavarria Parra',
#   '3037923293',
#   'gioparra@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Curlee',
#   'Thomas',
#   '3038646132',
#   'curleethomas9@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Edward',
#   'Hou',
#   '3033723307',
#   'eddhou@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Will', 'Roloson', '', 'kobay@berkeley.edu', '', '', '35', 'Missing'],
#  ['Yuki',
#   'Hamachi',
#   '3038033130',
#   'yuki1010@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['test5', 'test5', '', 'test5@test.com', '', '', '35', 'Missing'],
#  ['Angel',
#   'Mora Argueta',
#   '3040111597',
#   'angelmoraargueta@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Zahra',
#   'Mokhtari',
#   '3040528611',
#   'zahra_mokhtari@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Gennalyn',
#   'Torres',
#   '3040583471',
#   'gennalynmayberkeley@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Edwin',
#   'Ruiz-Rodriguez',
#   '3040223761',
#   'edwinruiz@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Kaixing',
#   'Zhang',
#   '3040937812',
#   'keson@berkeley.edu',
#   '',
#   '',
#   '35',
#   'Missing'],
#  ['Erin',
#   'ZHOU',
#   '3040947731',
#   'uerinzhou@berkeley.edu',
#   '',
#   '',
#   '35',
#   'Missing'],
#  ['Efe',
#   'Atli',
#   '23772813',
#   'eatli@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Felipe',
#   'Ruiz-Tagle',
#   '3040705060',
#   'felipe.ruiztagle@berkeley.edu',
#   'compsci-10-dis-801-in-person',
#   '',
#   '35',
#   'Missing'],
#  ['Jerome',
#   'Martel',
#   '',
#   'jerome.martel.t@berkeley.edu',
#   '',
#   '',
#   '35',
#   'Missing']]

# %%
df = convert_to_dataframe(raw_data)
df.head()
# Out:
#   b'First Name Last Name         SID                         Email  \
# 0        Anita      Qian  3040005244       anita_qian@berkeley.edu
# 1    Malachite    McEvoy  3036547996  malachitemcevoy@berkeley.edu
# 2      Abigail   Johnson  3040928660  abigail.johnson@berkeley.edu
# 3         Jack     Hulse  3040081294        johnhulse@berkeley.edu
# 4        Kelly      Chou  3038568093        kelly0919@berkeley.edu
#
#                        Sections Total Score Max Points  Status Submission ID  \
# 0  compsci-10-dis-801-in-person          35         35  Graded     314621931
# 1  compsci-10-dis-801-in-person          35         35  Graded     314680106
# 2  compsci-10-dis-801-in-person          35         35  Graded     314713498
# 3  compsci-10-dis-801-in-person          35         35  Graded     314713498
# 4  compsci-10-dis-801-in-person       30.35         35  Graded     314886910
#
#              Submission Time Lateness (H:M:S) View Count Submission Count  \
# 0  2025-03-05 10:45:24 -0800          0:00:00          0                1
# 1  2025-03-05 13:17:20 -0800          0:00:00          0                2
# 2  2025-03-05 14:46:33 -0800          0:00:00          0                1
# 3  2025-03-05 14:46:33 -0800          0:00:00          0                1
# 4  2025-03-06 00:34:41 -0800          0:00:00          0                1
#
#   1: Autograder (35.0 pts)
# 0                       35
# 1                       35
# 2                       35
# 3                       35
# 4                    30.35

# %%
def clean_assignment_df(df, tab_name):
    """
    Cleans and formats a Google Sheets assignment DataFrame:
    - Filters relevant columns
    - Adds an 'assignment' column using the provided tab name
    - Renames columns, reorders them, and standardizes the formatting

    Args:
        df (pd.DataFrame): Raw DataFrame from Google Sheets
        tab_name (str): Name of the Google Sheet tab (used as assignment label)

    Returns:
        pd.DataFrame: Cleaned and formatted DataFrame
    """
    required_columns = ["b'First Name", 'Last Name', 'SID', 'Email', 'Status', 'Submission Time', 'Lateness (H:M:S)']
    missing = [col for col in required_columns if col not in df.columns]
    if missing:
        raise ValueError(f"Missing columns in input DataFrame: {missing}")
    
    # Filter and format
    filtered_df = df[required_columns].copy()
    filtered_df['Assignment'] = tab_name
    filtered_df = filtered_df[['Assignment'] + required_columns]
    filtered_df.rename(columns={"b'First Name": 'First Name'}, inplace=True)
    filtered_df.columns = filtered_df.columns.str.lower().str.strip()

    return filtered_df

# %%
cleaned_df = clean_assignment_df(df, tab)
cleaned_df
# Out:
#          assignment first name   last name         sid  \
# 0   Project 3: 2048      Anita        Qian  3040005244
# 1   Project 3: 2048  Malachite      McEvoy  3036547996
# 2   Project 3: 2048    Abigail     Johnson  3040928660
# 3   Project 3: 2048       Jack       Hulse  3040081294
# 4   Project 3: 2048      Kelly        Chou  3038568093
# ..              ...        ...         ...         ...
# 60  Project 3: 2048    Kaixing       Zhang  3040937812
# 61  Project 3: 2048       Erin        ZHOU  3040947731
# 62  Project 3: 2048        Efe        Atli    23772813
# 63  Project 3: 2048     Felipe  Ruiz-Tagle  3040705060
# 64  Project 3: 2048     Jerome      Martel
#
#                             email   status            submission time  \
# 0         anita_qian@berkeley.edu   Graded  2025-03-05 10:45:24 -0800
# 1    malachitemcevoy@berkeley.edu   Graded  2025-03-05 13:17:20 -0800
# 2    abigail.johnson@berkeley.edu   Graded  2025-03-05 14:46:33 -0800
# 3          johnhulse@berkeley.edu   Graded  2025-03-05 14:46:33 -0800
# 4          kelly0919@berkeley.edu   Graded  2025-03-06 00:34:41 -0800
# ..                            ...      ...                        ...
# 60             keson@berkeley.edu  Missing
# 61         uerinzhou@berkeley.edu  Missing
# 62             eatli@berkeley.edu  Missing
# 63  felipe.ruiztagle@berkeley.edu  Missing
# 64   jerome.martel.t@berkeley.edu  Missing
#
#    lateness (h:m:s)
# 0           0:00:00
# 1           0:00:00
# 2           0:00:00
# 3           0:00:00
# 4           0:00:00
# ..              ...
# 60
# 61
# 62
# 63
# 64
#
# [65 rows x 8 columns]

# %%
# Get the output folder
import os

# Assuming your credentials are in a folder named 'output' in the current working directory
output_folder = os.path.join(os.getcwd(), 'output')
output_folder
# Out:
# '/Users/mananbhargava/Documents/Workspaces/dan-cs-ed/remind/gradesync_input/output'

# %%
output_filename = f"{tab}.csv"
output_path = os.path.join(output_folder, output_filename)
cleaned_df.to_csv(output_path, index=False)
print(f"Saved {output_path}")
print(f"Saved {tab}.csv")
# Out:
# Saved /Users/mananbhargava/Documents/Workspaces/dan-cs-ed/remind/gradesync_input/output/Project 3: 2048.csv
# Saved Project 3: 2048.csv
